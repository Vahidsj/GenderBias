# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import re

from collections import defaultdict

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Dataset Card for Multi-Dimensional Gender Bias Classification [LINK](https://huggingface.co/datasets/md_gender_bias)

# %% [markdown]
# **Dataset Summary**
#
#
# The Multi-Dimensional Gender Bias Classification dataset is based on a general framework that decomposes gender bias in text along several pragmatic and semantic dimensions: bias from the gender of the person being spoken about, bias from the gender of the person being spoken to, and bias from the gender of the speaker. It contains seven large scale datasets automatically annotated for gender information (there are eight in the original project but the Wikipedia set is not included in the HuggingFace distribution), one crowdsourced evaluation benchmark of utterance-level gender rewrites, a list of gendered names, and a list of gendered words in English.

# %% [markdown]
# **New_data config**
#
# - **text:** the text to be classified
# - **original:** the text before reformulation
# - **labels:** a list of classification labels, with possible values including ABOUT:female, ABOUT:male, PARTNER:female, PARTNER:male, SELF:female.
# - **class_type:** a classification label, with possible values including about (0), partner (1), self (2).
# - **turker_gender:** a classification label, with possible values including man (0), woman (1), nonbinary (2), prefer not to say (3), no answer (4).
# - **episode_done:** a boolean indicating whether the conversation was completed.
# - **confidence:** a string indicating the confidence of the annotator in response to the instance label being ABOUT/TO/AS a man or woman. Possible values are certain, pretty sure, and unsure.

# %%
# Training set
dataset_new_data_train = load_dataset("md_gender_bias", name='new_data', split='train')
dataset_new_data_train
# Out:
# Reusing dataset md_gender_bias (/Users/vahidsj/.cache/huggingface/datasets/md_gender_bias/new_data/1.0.0/8ae77b51acf93383161cc954b146159291beca6c979b54ce228c46db86116c05)
# Dataset({
#     features: ['text', 'original', 'labels', 'class_type', 'turker_gender', 'episode_done', 'confidence'],
#     num_rows: 2345
# })

# %%
df_new_data_train = dataset_new_data_train.to_pandas()
df_new_data_train
# Out:
#                                                    text  \
# 0     He designed monumental Lovissa War Cemetery in...
# 1                 She works as a volunteer firefighter.
# 2     She participated in the FIVB volleyball grand ...
# 3     Correct ! Walter Havighurst was an author of m...
# 4     Yes, she released only one album with them, "w...
# ...                                                 ...
# 2340           I am fine today bro. What about you Jim?
# 2341  Cool, well I was born in France among pretty g...
# 2342  Yeah man, I have women's intuition you are rig...
# 2343  Her name is lenoris and she just finished her ...
# 2344                          Nice to meet you Belinda.
#
#                                                original labels  class_type  \
# 0      She designed monumental Loviisa war cemetery ...    [1]           0
# 1                    I work as a volunteer firefighter.    [4]           2
# ...

# %%
def tuplizer(x):
    return tuple(x) if isinstance(x, (np.ndarray, list)) else x

# %%
df_new_data_train.labels.apply(tuplizer).unique()
# Out:
# array([(1,), (4,), (0,), (5,), (3,), (2,)], dtype=object)

# %% [markdown]
# **Funpedia config:**
#
# - **text:** the text to be classified.
# - **gender:** a classification label, with possible values including gender-neutral (0), female (1), male (2), indicating the gender of the person being talked about.
# - **persona:** a string describing the persona assigned to the user when talking about the entity.
# - **title:** a string naming the entity the text is about.

# %%
# Training set
dataset_funpedia_train = load_dataset("md_gender_bias", name='funpedia', split='train')
dataset_funpedia_train
# Out:
# Reusing dataset md_gender_bias (/Users/vahidsj/.cache/huggingface/datasets/md_gender_bias/funpedia/1.0.0/8ae77b51acf93383161cc954b146159291beca6c979b54ce228c46db86116c05)
# Dataset({
#     features: ['text', 'title', 'persona', 'gender'],
#     num_rows: 23897
# })

# %%
df_funpedia_train = dataset_funpedia_train.to_pandas()
df_funpedia_train
# Out:
#                                                     text             title  \
# 0      Max Landis is a comic book writer who wrote Ch...        Max Landis
# 1      Félix stevens is a retired cuban sprinter who ...     Félix Stevens
# 2      Arthur Engelbert is a professor at the Univers...  Arthur Engelbert
# 3       Danielle Frenkel is a high jumper born in Israel  Danielle Frenkel
# 4      Ernie O'Malley served in the Irish republican ...    Ernie O'Malley
# ...                                                  ...               ...
# 23892  If Cristian Rosso can win 2 gold medals in the...    Cristian Rosso
# 23893  With altitudes ranging from a low 700 to a who...  Wayanad district
# 23894  You can easily say that Cash Generator is the ...    Cash Generator
# 23895  Eleanor Mosley (Elinor Mosely) (1700-?) when d...    Eleanor Mosley
# 23896  Timothy Steele stands firm that he writes poet...    Timothy Steele
#
#           persona  gender
# 0        Humorous       2
# ...

# %%
# Test set
dataset_funpedia_test = load_dataset("md_gender_bias", name='funpedia', split='test')
# Out:
# Reusing dataset md_gender_bias (/Users/vahidsj/.cache/huggingface/datasets/md_gender_bias/funpedia/1.0.0/8ae77b51acf93383161cc954b146159291beca6c979b54ce228c46db86116c05)

# %%
df_funpedia_test = dataset_funpedia_test.to_pandas()
df_funpedia_test
# Out:
#                                                    text  \
# 0     Hmmm yes Horacio Calcaterra is a sportsman tha...
# 1     John A. Fallon kindly accepted his appointment...
# 2     Arthur Knight sadly passed as a result of part...
# 3     I cannot believe you've never seen Pani Pani R...
# 4       Of course his legacy was that of the Taniguchi.
# ...                                                 ...
# 2933  Sarah Phillips is respected throughout the com...
# 2934  Ruth Cohn created theme-centered interaction, ...
# 2935  Sonny Curtis was born on May 9th in 1937 and w...
# 2936  As soon as the first season of prison break wa...
# 2937  Harvey Manger-Weil had a heart for seeing othe...
#
#                           title                               persona  gender
# 0            Horacio Calcaterra  Articulate (Well-spoken, Expressive)       2
# 1                John A. Fallon                                Humble       2
# ...

# %%
df_funpedia_train.gender.unique()
# Out:
# array([2, 1, 0])

# %%
# Female = 1 & Male = 2

df_male_female = df_funpedia_train[df_funpedia_train.gender != 0]

print("Number of Females:", df_male_female[df_male_female.gender == 1].shape[0])
print("Number of Males:", df_male_female[df_male_female.gender == 2].shape[0])
# Out:
# Number of Females: 3594
# Number of Males: 19156

# %% [markdown]
# ## Twitter User Gender Classification [LINK](https://www.kaggle.com/code/kinguistics/classifying-user-gender-based-on-tweet-text)

# %%
df_twitter_gender_original = pd.read_csv("/Users/vahidsj/Documents/Work/Work_MARTIN/Gender Bias/Datasets/twitterText.csv", encoding='latin1')
df_twitter_gender_original
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0      815719226    False   finalized                   3    10/26/15 23:24
# 1      815719227    False   finalized                   3    10/26/15 23:30
# 2      815719228    False   finalized                   3    10/26/15 23:33
# 3      815719229    False   finalized                   3    10/26/15 23:10
# 4      815719230    False   finalized                   3     10/27/15 1:15
# ...          ...      ...         ...                 ...               ...
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
# ...

# %%
df_twitter_gender_original.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'gender', 'gender:confidence', 'profile_yn',
#        'profile_yn:confidence', 'created', 'description', 'fav_number',
#        'gender_gold', 'link_color', 'name', 'profile_yn_gold', 'profileimage',
#        'retweet_count', 'sidebar_color', 'text', 'tweet_coord', 'tweet_count',
#        'tweet_created', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df_twitter_gender = df_twitter_gender_original[['gender', 'gender:confidence', 'text']]
df_twitter_gender
# Out:
#        gender  gender:confidence  \
# 0        male             1.0000
# 1        male             1.0000
# 2        male             0.6625
# 3        male             1.0000
# 4      female             1.0000
# ...       ...                ...
# 20045  female             1.0000
# 20046    male             1.0000
# 20047    male             1.0000
# 20048  female             0.8489
# 20049  female             1.0000
#
#                                                     text
# 0      Robbie E Responds To Critics After Win Against...
# 1      ÛÏIt felt like they were my friends and I was...
# 2      i absolutely adore when louis starts the songs...
# 3      Hi @JordanSpieth - Looking at the url - do you...
# 4      Watching Neighbours on Sky+ catching up with t...
# ...                                                  ...
# 20045  @lookupondeath ...Fine, and I'll drink tea too...
# 20046  Greg Hardy you a good player and all but don't...
# ...

# %%
def clean_tweet(text):
    # Remove mention, URL and #
    text_cleaned = re.sub(r'(@|https?)\S+|#', '', text)
    # Remove special characters
    text_cleaned = re.sub('[^A-Za-z0-9;,!?.-]+', ' ', text_cleaned)
    # make sure we didn't introduce any double spaces
    text_cleaned = re.sub('\s+',' ',text_cleaned)
    return(text_cleaned)

# %%
df_twitter_gender_cleaned = df_twitter_gender.copy()
df_twitter_gender_cleaned['text'] = df_twitter_gender_cleaned['text'].apply(clean_tweet)

# %%
df_twitter_gender_cleaned
# Out:
#        gender  gender:confidence  \
# 0        male             1.0000
# 1        male             1.0000
# 2        male             0.6625
# 3        male             1.0000
# 4      female             1.0000
# ...       ...                ...
# 20045  female             1.0000
# 20046    male             1.0000
# 20047    male             1.0000
# 20048  female             0.8489
# 20049  female             1.0000
#
#                                                     text
# 0      Robbie E Responds To Critics After Win Against...
# 1       It felt like they were my friends and I was l...
# 2      i absolutely adore when louis starts the songs...
# 3      Hi - Looking at the url - do you use Don t typ...
# 4      Watching Neighbours on Sky catching up with th...
# ...                                                  ...
# 20045       ...Fine, and I ll drink tea too. I love you.
# 20046  Greg Hardy you a good player and all but don t...
# ...

# %%
df_twitter_gender_cleaned.gender.unique()
# Out:
# array(['male', 'female', 'brand', 'unknown', nan], dtype=object)

# %%
# Only male and female
df_twitter_gender_cleaned = df_twitter_gender_cleaned[df_twitter_gender_cleaned['gender'].isin(['male', 'female'])]
df_twitter_gender_cleaned
# Out:
#        gender  gender:confidence  \
# 0        male             1.0000
# 1        male             1.0000
# 2        male             0.6625
# 3        male             1.0000
# 4      female             1.0000
# ...       ...                ...
# 20045  female             1.0000
# 20046    male             1.0000
# 20047    male             1.0000
# 20048  female             0.8489
# 20049  female             1.0000
#
#                                                     text
# 0      Robbie E Responds To Critics After Win Against...
# 1       It felt like they were my friends and I was l...
# 2      i absolutely adore when louis starts the songs...
# 3      Hi - Looking at the url - do you use Don t typ...
# 4      Watching Neighbours on Sky catching up with th...
# ...                                                  ...
# 20045       ...Fine, and I ll drink tea too. I love you.
# 20046  Greg Hardy you a good player and all but don t...
# ...

# %%
df_twitter_gender_cleaned.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Only confidence = 1
df_twitter_gender_cleaned = df_twitter_gender_cleaned[df_twitter_gender_cleaned['gender:confidence']==1]
df_twitter_gender_cleaned
# Out:
#        gender  gender:confidence  \
# 0        male                1.0
# 1        male                1.0
# 3        male                1.0
# 4      female                1.0
# 5      female                1.0
# ...       ...                ...
# 20044  female                1.0
# 20045  female                1.0
# 20046    male                1.0
# 20047    male                1.0
# 20049  female                1.0
#
#                                                     text
# 0      Robbie E Responds To Critics After Win Against...
# 1       It felt like they were my friends and I was l...
# 3      Hi - Looking at the url - do you use Don t typ...
# 4      Watching Neighbours on Sky catching up with th...
# 5      Ive seen people on the train with lamps, chair...
# ...                                                  ...
# 20044  Need A Ride Home From Practice And its Raining...
# 20045       ...Fine, and I ll drink tea too. I love you.
# ...

# %%
# None Values
df_twitter_gender_cleaned.isnull().values.any()
# Out:
# False

# %%
# Training a model using CountVectorizer

count_vectorizer = CountVectorizer()
x = count_vectorizer.fit_transform(df_twitter_gender_cleaned['text'])

encoder = LabelEncoder()
y = encoder.fit_transform(df_twitter_gender_cleaned['gender'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print('Traing set:', x_train.shape)
print('Test set', x_test.shape)

nb = MultinomialNB()
nb.fit(x_train, y_train)

print(nb.score(x_test, y_test))
# Out:
# Traing set: (8016, 16964)
# Test set (2004, 16964)
# 0.6272455089820359

# %%
# Training a model using TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(df_twitter_gender_cleaned['text'])

encoder = LabelEncoder()
y = encoder.fit_transform(df_twitter_gender_cleaned['gender'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print('Traing set:', x_train.shape)
print('Test set', x_test.shape)

nb = MultinomialNB()
nb.fit(x_train, y_train)

print(nb.score(x_test, y_test))
# Out:
# Traing set: (8016, 16964)
# Test set (2004, 16964)
# 0.6327345309381237

# %%
# Training a model using TfidfVectorizer - SVM

tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(df_twitter_gender_cleaned['text'])

encoder = LabelEncoder()
y = encoder.fit_transform(df_twitter_gender_cleaned['gender'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print('Traing set:', x_train.shape)
print('Test set', x_test.shape)

svm = SVC()
svm.fit(x_train, y_train)

print(svm.score(x_test, y_test))
# Out:
# Traing set: (8016, 16964)
# Test set (2004, 16964)
# 0.592814371257485

# %%
# Training a model using TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(df_twitter_gender_cleaned['text'])

encoder = LabelEncoder()
y = encoder.fit_transform(df_twitter_gender_cleaned['gender'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print('Traing set:', x_train.shape)
print('Test set', x_test.shape)

mlp = MLPClassifier()
mlp.fit(x_train, y_train)

print(mlp.score(x_test, y_test))
# Out:
# Traing set: (8016, 16964)
# Test set (2004, 16964)
# 0.56187624750499

# %%
y_pred = nb.predict(x_test)

cm = confusion_matrix(y_pred, y_test)
print("\nConfusion matrix: \n")
print(cm)
# Out:
# Confusion matrix:
#
# [[938 279]
#  [110 677]]

# %% [markdown]
# ## Blog Authorship Corpus [LINK](https://www.kaggle.com/datasets/rtatman/blog-authorship-corpus)

# %%
df_blog_gender_original = pd.read_csv("/Users/vahidsj/Documents/Work/Work_MARTIN/Gender Bias/Datasets/blogText.csv")
df_blog_gender_original
# Out:
#              id gender  age              topic      sign          date  \
# 0       2059027   male   15            Student       Leo   14,May,2004
# 1       2059027   male   15            Student       Leo   13,May,2004
# 2       2059027   male   15            Student       Leo   12,May,2004
# 3       2059027   male   15            Student       Leo   12,May,2004
# 4       3581210   male   33  InvestmentBanking  Aquarius  11,June,2004
# ...         ...    ...  ...                ...       ...           ...
# 681279  1713845   male   23            Student    Taurus  01,July,2004
# 681280  1713845   male   23            Student    Taurus  01,July,2004
# 681281  1713845   male   23            Student    Taurus  01,July,2004
# 681282  1713845   male   23            Student    Taurus  01,July,2004
# 681283  1713845   male   23            Student    Taurus  01,July,2004
#
#                                                      text
# ...

# %%
df_blog_gender_original.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df_blog_gender_original[df_blog_gender_original.gender == 'male']
# Out:
#              id gender  age              topic      sign          date  \
# 0       2059027   male   15            Student       Leo   14,May,2004
# 1       2059027   male   15            Student       Leo   13,May,2004
# 2       2059027   male   15            Student       Leo   12,May,2004
# 3       2059027   male   15            Student       Leo   12,May,2004
# 4       3581210   male   33  InvestmentBanking  Aquarius  11,June,2004
# ...         ...    ...  ...                ...       ...           ...
# 681279  1713845   male   23            Student    Taurus  01,July,2004
# 681280  1713845   male   23            Student    Taurus  01,July,2004
# 681281  1713845   male   23            Student    Taurus  01,July,2004
# 681282  1713845   male   23            Student    Taurus  01,July,2004
# 681283  1713845   male   23            Student    Taurus  01,July,2004
#
#                                                      text
# ...

# %%
df_blog_gender_original[df_blog_gender_original.gender == 'female']
# Out:
#              id  gender  age   topic   sign            date  \
# 74      3539003  female   14  indUnk  Aries    07,June,2004
# 75      3539003  female   14  indUnk  Aries    05,June,2004
# 76      3539003  female   14  indUnk  Aries    05,June,2004
# 77      3539003  female   14  indUnk  Aries    05,June,2004
# 78      3539003  female   14  indUnk  Aries    04,June,2004
# ...         ...     ...  ...     ...    ...             ...
# 681156  4260903  female   34  indUnk  Virgo  23,August,2004
# 681157  4260903  female   34  indUnk  Virgo  21,August,2004
# 681158  4260903  female   34  indUnk  Virgo  19,August,2004
# 681159  4260903  female   34  indUnk  Virgo  18,August,2004
# 681160  4260903  female   34  indUnk  Virgo  18,August,2004
#
#                                                      text
# 74                        O= optimist P= pessimist  My...
# 75                        Look at me. Look at my eyes....
# 76                        I walk into the only entranc...
# ...

# %%
df_blog_gender_original.isnull().values.any()
# Out:
# False

# %%
df_blog_gender_original.sign.unique()
# Out:
# array(['Leo', 'Aquarius', 'Aries', 'Capricorn', 'Gemini', 'Cancer',
#        'Sagittarius', 'Scorpio', 'Libra', 'Virgo', 'Taurus', 'Pisces'],
#       dtype=object)

# %%
# Training a model using CountVectorizer

count_vectorizer = CountVectorizer()
x = count_vectorizer.fit_transform(df_blog_gender_original['text'])

encoder = LabelEncoder()
y = encoder.fit_transform(df_blog_gender_original['gender'])

# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print('Traing set:', x_train.shape)
print('Test set', x_test.shape)

nb = MultinomialNB()
nb.fit(x_train, y_train)

print(nb.score(x_test, y_test))
# Out:
# Traing set: (545027, 721129)
# Test set (136257, 721129)
# 0.6718480518432081

# %% [markdown]
# # Analyzing Bias

# %%
count_vectorizer = CountVectorizer()
x_count_vectorizer = count_vectorizer.fit_transform(df_blog_gender_original['text'])

encoder = LabelEncoder()
y_count_vectorizer = encoder.fit_transform(df_blog_gender_original['sign'])


tfidf_vectorizer = TfidfVectorizer()
x_tfidf_vectorizer = tfidf_vectorizer.fit_transform(df_blog_gender_original['text'])

y_tfidf_vectorizer = encoder.fit_transform(df_blog_gender_original['sign'])

# %% [markdown]
# ### 1. Default (test_size=0.3)

# %%
# Training a model using CountVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_count, x_test_count, y_train_count, y_test_count = train_test_split(x_count_vectorizer, y_count_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_count, y_train_count)
    print('MultinomialNB Accuracy:', nb.score(x_test_count, y_test_count))
    
    #svm = SVC()
    #svm.fit(x_train_count, y_train_count)
    #print('SVM Accuracy:', nb.score(x_test_count, y_test_count))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_count, y_test_count))
    #scores_list_SVM.append(nb.score(x_test_count, y_test_count))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.24015343516679225
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.23891558130204613
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.2409509457594943
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.2408677698081082
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.24237472233910345
# ___________________
# MultinomialNB - Average of accuracy: 0.24065249087510887

# %%
# Training a model using TfidfVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_tfidf, x_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(x_tfidf_vectorizer, y_tfidf_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_tfidf, y_train_tfidf)
    print('MultinomialNB Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))
    
    #svm = SVC()
    #svm.fit(x_train_tfidf, y_train_tfidf)
    #print('SVM Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_tfidf, y_test_tfidf))
    #scores_list_SVM.append(nb.score(x_test_tfidf, y_test_tfidf))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.2006252874463026
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.20323309815740803
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.2002143003923948
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.1974352450754944
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.19852631784955918
# ___________________
# MultinomialNB - Average of accuracy: 0.20000684978423178

# %% [markdown]
# ### 2. Baseline: 50/50 male/female

# %%
df_male = df_blog_gender_original[df_blog_gender_original.gender == 'male']
df_female = df_blog_gender_original[df_blog_gender_original.gender == 'female']

print('DF male:',df_male.shape)
print('DF female', df_female.shape)
# Out:
# DF male: (345193, 7)
# DF female (336091, 7)

# %%
new_df_male = df_male.iloc[:336091, :]

print('DF male:',new_df_male.shape)
print('DF female', df_female.shape)
# Out:
# DF male: (336091, 7)
# DF female (336091, 7)

# %%
df_blog_gender_original_new = pd.concat([new_df_male, df_female], ignore_index=True)
df_blog_gender_original_new
# Out:
#              id  gender  age              topic      sign            date  \
# 0       2059027    male   15            Student       Leo     14,May,2004
# 1       2059027    male   15            Student       Leo     13,May,2004
# 2       2059027    male   15            Student       Leo     12,May,2004
# 3       2059027    male   15            Student       Leo     12,May,2004
# 4       3581210    male   33  InvestmentBanking  Aquarius    11,June,2004
# ...         ...     ...  ...                ...       ...             ...
# 672177  4260903  female   34             indUnk     Virgo  23,August,2004
# 672178  4260903  female   34             indUnk     Virgo  21,August,2004
# 672179  4260903  female   34             indUnk     Virgo  19,August,2004
# 672180  4260903  female   34             indUnk     Virgo  18,August,2004
# 672181  4260903  female   34             indUnk     Virgo  18,August,2004
#
#                                                      text
# ...

# %%
df_male_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'male']
df_female_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'female']

print('DF male:',df_male_new.shape)
print('DF female', df_female_new.shape)
# Out:
# DF male: (336091, 7)
# DF female (336091, 7)

# %%
count_vectorizer = CountVectorizer()
x_count_vectorizer = count_vectorizer.fit_transform(df_blog_gender_original_new['text'])

encoder = LabelEncoder()
y_count_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])


tfidf_vectorizer = TfidfVectorizer()
x_tfidf_vectorizer = tfidf_vectorizer.fit_transform(df_blog_gender_original_new['text'])

y_tfidf_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])

# %%
# Training a model using CountVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_count, x_test_count, y_train_count, y_test_count = train_test_split(x_count_vectorizer, y_count_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_count, y_train_count)
    print('MultinomialNB Accuracy:', nb.score(x_test_count, y_test_count))
    
    #svm = SVC()
    #svm.fit(x_train_count, y_train_count)
    #print('SVM Accuracy:', nb.score(x_test_count, y_test_count))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_count, y_test_count))
    #scores_list_SVM.append(nb.score(x_test_count, y_test_count))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.24023207954179168
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.24320745828271056
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.24088170390022565
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.2417594406287967
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.24324217103468795
# ___________________
# MultinomialNB - Average of accuracy: 0.2418645706776425

# %%
# Training a model using TfidfVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_tfidf, x_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(x_tfidf_vectorizer, y_tfidf_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_tfidf, y_train_tfidf)
    print('MultinomialNB Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))
    
    #svm = SVC()
    #svm.fit(x_train_tfidf, y_train_tfidf)
    #print('SVM Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_tfidf, y_test_tfidf))
    #scores_list_SVM.append(nb.score(x_test_tfidf, y_test_tfidf))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.19931566288958866
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.19878009471622327
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.1967816319952394
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.19924623738563388
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.20092732637425306
# ___________________
# MultinomialNB - Average of accuracy: 0.19901019067218764

# %% [markdown]
# ### 3. 25/75 male/female

# %%
df_male = df_blog_gender_original[df_blog_gender_original.gender == 'male']
df_female = df_blog_gender_original[df_blog_gender_original.gender == 'female']

print('DF male:',df_male.shape)
print('DF female', df_female.shape)
# Out:
# DF male: (345193, 7)
# DF female (336091, 7)

# %%
_25 = int((336091 * 25)/100)

new_df_male = df_male.iloc[:_25, :]

print('DF male:',new_df_male.shape)
print('DF female', df_female.shape)
# Out:
# DF male: (84022, 7)
# DF female (336091, 7)

# %%
df_blog_gender_original_new = pd.concat([new_df_male, df_female], ignore_index=True)
df_blog_gender_original_new
# Out:
#              id  gender  age              topic      sign            date  \
# 0       2059027    male   15            Student       Leo     14,May,2004
# 1       2059027    male   15            Student       Leo     13,May,2004
# 2       2059027    male   15            Student       Leo     12,May,2004
# 3       2059027    male   15            Student       Leo     12,May,2004
# 4       3581210    male   33  InvestmentBanking  Aquarius    11,June,2004
# ...         ...     ...  ...                ...       ...             ...
# 420108  4260903  female   34             indUnk     Virgo  23,August,2004
# 420109  4260903  female   34             indUnk     Virgo  21,August,2004
# 420110  4260903  female   34             indUnk     Virgo  19,August,2004
# 420111  4260903  female   34             indUnk     Virgo  18,August,2004
# 420112  4260903  female   34             indUnk     Virgo  18,August,2004
#
#                                                      text
# ...

# %%
df_male_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'male']
df_female_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'female']

print('DF male:',df_male_new.shape)
print('DF female', df_female_new.shape)
# Out:
# DF male: (84022, 7)
# DF female (336091, 7)

# %%
count_vectorizer = CountVectorizer()
x_count_vectorizer = count_vectorizer.fit_transform(df_blog_gender_original_new['text'])

encoder = LabelEncoder()
y_count_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])


tfidf_vectorizer = TfidfVectorizer()
x_tfidf_vectorizer = tfidf_vectorizer.fit_transform(df_blog_gender_original_new['text'])

y_tfidf_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])

# %%
# Training a model using CountVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_count, x_test_count, y_train_count, y_test_count = train_test_split(x_count_vectorizer, y_count_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_count, y_train_count)
    print('MultinomialNB Accuracy:', nb.score(x_test_count, y_test_count))
    
    #svm = SVC()
    #svm.fit(x_train_count, y_train_count)
    #print('SVM Accuracy:', nb.score(x_test_count, y_test_count))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_count, y_test_count))
    #scores_list_SVM.append(nb.score(x_test_count, y_test_count))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.27111731754923274
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.27181554183791673
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.27260104416268627
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.2706491899011378
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.2715378389958265
# ___________________
# MultinomialNB - Average of accuracy: 0.27154418648936

# %%
# Training a model using TfidfVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_tfidf, x_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(x_tfidf_vectorizer, y_tfidf_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_tfidf, y_train_tfidf)
    print('MultinomialNB Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))
    
    #svm = SVC()
    #svm.fit(x_train_tfidf, y_train_tfidf)
    #print('SVM Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_tfidf, y_test_tfidf))
    #scores_list_SVM.append(nb.score(x_test_tfidf, y_test_tfidf))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.22673246901629718
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.22344764111271562
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.22388403129314313
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.22551851087801705
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.22518526746750878
# ___________________
# MultinomialNB - Average of accuracy: 0.22495358395353637

# %% [markdown]
# ### 4. 75/25 male/female

# %%
df_male = df_blog_gender_original[df_blog_gender_original.gender == 'male']
df_female = df_blog_gender_original[df_blog_gender_original.gender == 'female']

print('DF male:',df_male.shape)
print('DF female', df_female.shape)
# Out:
# DF male: (345193, 7)
# DF female (336091, 7)

# %%
_25 = int((345193 * 25)/100)

new_df_female= df_female.iloc[:_25, :]

print('DF male:', df_male.shape)
print('DF female', new_df_female.shape)
# Out:
# DF male: (345193, 7)
# DF female (86298, 7)

# %%
df_blog_gender_original_new = pd.concat([df_male, new_df_female], ignore_index=True)
df_blog_gender_original_new
# Out:
#              id  gender  age              topic      sign            date  \
# 0       2059027    male   15            Student       Leo     14,May,2004
# 1       2059027    male   15            Student       Leo     13,May,2004
# 2       2059027    male   15            Student       Leo     12,May,2004
# 3       2059027    male   15            Student       Leo     12,May,2004
# 4       3581210    male   33  InvestmentBanking  Aquarius    11,June,2004
# ...         ...     ...  ...                ...       ...             ...
# 431486  1056232  female   17             indUnk  Aquarius  09,August,2004
# 431487  1056232  female   17             indUnk  Aquarius  09,August,2004
# 431488  1056232  female   17             indUnk  Aquarius  09,August,2004
# 431489  1056232  female   17             indUnk  Aquarius  09,August,2004
# 431490  1056232  female   17             indUnk  Aquarius  09,August,2004
#
#                                                      text
# ...

# %%
df_male_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'male']
df_female_new = df_blog_gender_original_new[df_blog_gender_original_new.gender == 'female']

print('DF male:',df_male_new.shape)
print('DF female', df_female_new.shape)
# Out:
# DF male: (345193, 7)
# DF female (86298, 7)

# %%
count_vectorizer = CountVectorizer()
x_count_vectorizer = count_vectorizer.fit_transform(df_blog_gender_original_new['text'])

encoder = LabelEncoder()
y_count_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])


tfidf_vectorizer = TfidfVectorizer()
x_tfidf_vectorizer = tfidf_vectorizer.fit_transform(df_blog_gender_original_new['text'])

y_tfidf_vectorizer = encoder.fit_transform(df_blog_gender_original_new['sign'])

# %%
# Training a model using CountVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_count, x_test_count, y_train_count, y_test_count = train_test_split(x_count_vectorizer, y_count_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_count, y_train_count)
    print('MultinomialNB Accuracy:', nb.score(x_test_count, y_test_count))
    
    #svm = SVC()
    #svm.fit(x_train_count, y_train_count)
    #print('SVM Accuracy:', nb.score(x_test_count, y_test_count))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_count, y_test_count))
    #scores_list_SVM.append(nb.score(x_test_count, y_test_count))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.2528660156974229
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.25488999443792104
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.2531827451949818
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.25159137259749087
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.2502394784005933
# ___________________
# MultinomialNB - Average of accuracy: 0.252553921265682

# %%
# Training a model using TfidfVectorizer - MultinomialNB & SVM

scores_list_MultinomialNB = []
scores_list_SVM = []

for i in range(1,6):
    
    print('RUN #', str(i))

    # split into train and test sets
    x_train_tfidf, x_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(x_tfidf_vectorizer, y_tfidf_vectorizer, test_size=0.3)

    #print('Traing set:', x_train.shape)
    #print('Test set:', x_test.shape)

    nb = MultinomialNB()
    nb.fit(x_train_tfidf, y_train_tfidf)
    print('MultinomialNB Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))
    
    #svm = SVC()
    #svm.fit(x_train_tfidf, y_train_tfidf)
    #print('SVM Accuracy:', nb.score(x_test_tfidf, y_test_tfidf))

    print('___________________')
    
    scores_list_MultinomialNB.append(nb.score(x_test_tfidf, y_test_tfidf))
    #scores_list_SVM.append(nb.score(x_test_tfidf, y_test_tfidf))
    
print('MultinomialNB - Average of accuracy:', np.mean(scores_list_MultinomialNB))
#print('SVM - Average of accuracy:', np.mean(scores_list_SVM))
# Out:
# RUN # 1
# MultinomialNB Accuracy: 0.1974692540634077
# ___________________
# RUN # 2
# MultinomialNB Accuracy: 0.19482726654718496
# ___________________
# RUN # 3
# MultinomialNB Accuracy: 0.19621778629256537
# ___________________
# RUN # 4
# MultinomialNB Accuracy: 0.1966272171064829
# ___________________
# RUN # 5
# MultinomialNB Accuracy: 0.20018076756689945
# ___________________
# MultinomialNB - Average of accuracy: 0.19706445831530806
